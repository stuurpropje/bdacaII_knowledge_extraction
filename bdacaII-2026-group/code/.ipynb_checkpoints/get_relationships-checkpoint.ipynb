# %%
post_data = {
    "id": "post_12345",
    "created_at": "2024-01-15T14:30:00Z",
    "user": {
        "username": "data_journalist",
        "verified": True,
        "follower_count": 15420,
        "account_created": "2019-03-12"
    },
    "content": {
        "text": "New study on misinformation spread! Link in thread 4",
        "language": "en",
        "hashtags": ["misinformation", "research", "datasci"],
        "mentions": ["@university_lab", "@researcher_jane"]
    },
    "engagement": {
        "likes": 342,
        "reposts": 67,
        "replies": 23,
        "views": None  # Not all platforms provide view counts
    },
    "media": [
        {
            "type": "image",
            "url": "https://example.com/img1.jpg",
            "alt_text": "Chart showing misinformation trends"
        }
    ],
    "context_annotations": {
        "topics": [
            {"name": "Media Studies", "confidence": 0.89},
            {"name": "Academic Research", "confidence": 0.76}
        ]
    }
}

# %%
user_name = post_data["user"]["username"]

# %%
user_name
# Out:
# 'data_journalist'

# %%
post_data["content"]["text"]
# Out:
# 'New study on misinformation spread! Link in thread 4'

# %%
total_engagement = (
    post_data["engagement"]["likes"]
    + post_data["engagement"]["reposts"]
    + post_data["engagement"]["replies"]
)

# %%
total_engagement
# Out:
# 432
