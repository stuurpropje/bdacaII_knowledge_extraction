# %% [markdown]
# ### 00. Dependencies

# %%
from get_article_links import get_article_links_wikitext
import wptools

# %%
query = "Charles III"

# %% [markdown]
# ### 1. Number of references

# %%
links = get_article_links_wikitext(query, limit=1000)

print(len(links))
# Out:
# 618

# %%
page = wptools.page(query)
page.get_query(show=False)
page.get_more(show=False)
# Out:
# en.wikipedia.org (query) Charles III
# en.wikipedia.org (query) Charles III (&plcontinue=125248|0|HMS_An...
# en.wikipedia.org (query) Charles III (&plcontinue=125248|0|Monarc...
# en.wikipedia.org (query) Charles III (&plcontinue=125248|0|Vetted)
# en.wikipedia.org (imageinfo) File:King Charles III (July 2023).jpg
# en.wikipedia.org (querymore) 125248
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|171477)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|431132)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|1043188)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|2127417)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|4542874)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|9327967)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|16582024)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|25012928)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|32894925)
# en.wikipedia.org (querymore) 125248 (&blcontinue=0|41625720)
# ...

# %% [markdown]
# #### 1.1 Better way to get links

# %%
len(page.data["links"])
# Out:
# 1550

# %% [markdown]
# ### 2. Page length

# %%
page.data["length"]
# Out:
# 281668

# %% [markdown]
# ### 3. Languages

# %%
len(page.data["languages"])
# Out:
# 159
